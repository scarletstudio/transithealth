# %% [markdown]
# Remember in the terminal, do `run api 9` to run the server, then you can run your tests below. You can see the results in the terminal where you run the server.

# %%
#most recent version as of 7/20/21 8:04PM
import os
os.chdir("../../")
from flask import Blueprint, jsonify, request
from api.metrics.rent_burdened import RentBurdenedMetrics


def make_blueprint(con):
    """
    Creates blueprint for endpoints related to rent burdened households data.
    """

    app = Blueprint("rent_burdened", __name__)
    metric = RentBurdenedMetrics(con)

    @app.route("/rent_burdened/rent_burdened", methods=["POST"])
    def rent_burdened():
        """
        Returns the rent burdened households data by year.
        """
        
        body = request.get_json()
        rent_year = body["rent_burdened"] if "rent_burdened" in body else []
        return jsonify(metric.rent_burdened(rent_year, segment="all"))

    @app.route("/rent_burdened/max_burdened")
    def max_burdened():
        """
        Returns the maximum percentage of burdened households and its area.
        """
        return jsonify(metric.rent_max_burdened())
        
    @app.route("/rent_burdened/min_burdened")
    def min_burdened():
        """
        Returns the minimum percentage of burdened households and its area.
        """
        return jsonify(metric.rent_min_burdened())


    @app.route("/rent_burdened/average_burden")
    def average_burden():
        """
        Returns the average percentage of rent burdened households by area
        across all periods..
        """
        return jsonify(metric.rent_average_burden_area())
        
    @app.route("/rent_burdened/hello")
    def hello():
        return "hello"


    return app

# %%
import pandas as pd
import requests
r = requests.post('http://18.117.9.77:5000/rent_burdened/rent_burdened', json={'rent_burdened':2019}) #notice the post here
r.content
data = r.json()
data
# Out:
# [{'area_number': 35, 'value': 0.527029065195125},
#  {'area_number': 36, 'value': 0.416541886411246},
#  {'area_number': 37, 'value': 0.562945422971736},
#  {'area_number': 38, 'value': 0.514589913593531},
#  {'area_number': 39, 'value': 0.48790639029861},
#  {'area_number': 4, 'value': 0.339090007521057},
#  {'area_number': 40, 'value': 0.634529117743474},
#  {'area_number': 41, 'value': 0.556497101288519},
#  {'area_number': 42, 'value': 0.571333247083089},
#  {'area_number': 1, 'value': 0.521383822277451},
#  {'area_number': 11, 'value': 0.414553991402132},
#  {'area_number': 12, 'value': 0.36623665307074504},
#  {'area_number': 13, 'value': 0.382026162098048},
#  {'area_number': 14, 'value': 0.410365252573371},
#  {'area_number': 15, 'value': 0.41338077180496297},
#  {'area_number': 16, 'value': 0.372471509472506},
#  {'area_number': 17, 'value': 0.457928067607059},
#  {'area_number': 18, 'value': 0.57395063908161},
#  {'area_number': 19, 'value': 0.531455280060543},
#  {'area_number': 2, 'value': 0.5042860947911629},
#  {'area_number': 20, 'value': 0.520684979271121},
#  {'area_number': 21, 'value': 0.437222314953353},
#  {'area_number': 22, 'value': 0.354248822716347},
#  {'area_number': 23, 'value': 0.552650059532813},
#  {'area_number': 24, 'value': 0.311296805407702},
#  {'area_number': 25, 'value': 0.603018944193715},
#  {'area_number': 26, 'value': 0.6210363660466399},
#  {'area_number': 27, 'value': 0.5787364215702879},
#  {'area_number': 28, 'value': 0.405039591286569},
#  {'area_number': 29, 'value': 0.58633933827712},
#  {'area_number': 3, 'value': 0.441833763351831},
#  {'area_number': 30, 'value': 0.6031228138957421},
#  {'area_number': 31, 'value': 0.40463338413537303},
#  {'area_number': 33, 'value': 0.403698218685224},
#  {'area_number': 34, 'value': 0.393426867887001},
#  {'area_number': 10, 'value': 0.416921245760158},
#  {'area_number': 8, 'value': 0.352646869905949},
#  {'area_number': 32, 'value': 0.33820753824737404},
#  {'area_number': 43, 'value': 0.5242511064552791},
#  {'area_number': 44, 'value': 0.58864783737439},
#  {'area_number': 45, 'value': 0.629074653530553},
#  {'area_number': 46, 'value': 0.49605467107048},
#  {'area_number': 47, 'value': 0.766759337017302},
#  {'area_number': 48, 'value': 0.499907274108696},
#  {'area_number': 49, 'value': 0.544500800951192},
#  {'area_number': 5, 'value': 0.312998775863262},
#  {'area_number': 50, 'value': 0.43482538919602803},
#  {'area_number': 51, 'value': 0.367554348116302},
#  {'area_number': 52, 'value': 0.444038596283814},
#  {'area_number': 53, 'value': 0.555154708656327},
#  {'area_number': 54, 'value': 0.34764661129378605},
#  {'area_number': 55, 'value': 0.538267060937025},
#  {'area_number': 56, 'value': 0.38851930862789097},
#  {'area_number': 57, 'value': 0.476584571860405},
#  {'area_number': 58, 'value': 0.481742053470735},
#  {'area_number': 59, 'value': 0.5091369333153299},
#  {'area_number': 6, 'value': 0.327283528680598},
#  {'area_number': 60, 'value': 0.412403250671058},
#  {'area_number': 61, 'value': 0.46055415702997105},
#  {'area_number': 62, 'value': 0.43427610268985395},
#  {'area_number': 63, 'value': 0.529892054635748},
#  {'area_number': 64, 'value': 0.43228825443801},
#  {'area_number': 65, 'value': 0.601004720279579},
#  {'area_number': 66, 'value': 0.625744930066983},
#  {'area_number': 67, 'value': 0.618661261144841},
#  {'area_number': 68, 'value': 0.577129571258704},
#  {'area_number': 69, 'value': 0.578531937112175},
#  {'area_number': 7, 'value': 0.30562021615017904},
#  {'area_number': 70, 'value': 0.556494405908501},
#  {'area_number': 71, 'value': 0.572411619113418},
#  {'area_number': 72, 'value': 0.233531909596352},
#  {'area_number': 73, 'value': 0.539686851322617},
#  {'area_number': 74, 'value': 0.37815458007971203},
#  {'area_number': 75, 'value': 0.47192901139242205},
#  {'area_number': 76, 'value': 0.484751376092305},
#  {'area_number': 77, 'value': 0.42159057274701195},
#  {'area_number': 9, 'value': 0.44909625014735605}]

# %%
import pandas as pd
import requests
r = requests.get('http://18.117.9.77:5000/rent_burdened/average_burden') #notice the post here
r.content
data = r.json()
data
# Out:
# [{'area_number': 1, 'value': 0.5302510978679696},
#  {'area_number': 2, 'value': 0.5097283445447782},
#  {'area_number': 3, 'value': 0.43211213106324214},
#  {'area_number': 4, 'value': 0.35123187692461},
#  {'area_number': 5, 'value': 0.32225627041653804},
#  {'area_number': 6, 'value': 0.33942125682913643},
#  {'area_number': 7, 'value': 0.3385054789413935},
#  {'area_number': 8, 'value': 0.3495706737217485},
#  {'area_number': 9, 'value': 0.33893145147465226},
#  {'area_number': 10, 'value': 0.42286894756722837},
#  {'area_number': 11, 'value': 0.401999365909452},
#  {'area_number': 12, 'value': 0.40967282140644024},
#  {'area_number': 13, 'value': 0.34330849046565104},
#  {'area_number': 14, 'value': 0.43901106359040076},
#  {'area_number': 15, 'value': 0.4157247713333986},
#  {'area_number': 16, 'value': 0.4044859748794217},
#  {'area_number': 17, 'value': 0.4771031485331919},
#  {'area_number': 18, 'value': 0.5294937789435444},
#  {'area_number': 19, 'value': 0.5568022009956136},
#  {'area_number': 20, 'value': 0.6077718584419536},
#  {'area_number': 21, 'value': 0.47377858881045926},
#  {'area_number': 22, 'value': 0.3809871512534564},
#  {'area_number': 23, 'value': 0.5453405908186649},
#  {'area_number': 24, 'value': 0.35100620598223975},
#  {'area_number': 25, 'value': 0.618917371580634},
#  {'area_number': 26, 'value': 0.610321056562379},
#  {'area_number': 27, 'value': 0.5769892800441351},
#  {'area_number': 28, 'value': 0.4035301097271294},
#  {'area_number': 29, 'value': 0.6003365352695959},
#  {'area_number': 30, 'value': 0.5700280771301859},
#  {'area_number': 31, 'value': 0.4055336637396056},
#  {'area_number': 32, 'value': 0.35065459609223915},
#  {'area_number': 33, 'value': 0.4645410730297184},
#  {'area_number': 34, 'value': 0.43351909690229795},
#  {'area_number': 35, 'value': 0.5485484578548134},
#  {'area_number': 36, 'value': 0.45494303455371},
#  {'area_number': 37, 'value': 0.6030153743235958},
#  {'area_number': 38, 'value': 0.5251129366003754},
#  {'area_number': 39, 'value': 0.5044523809272752},
#  {'area_number': 40, 'value': 0.5980414424092976},
#  {'area_number': 41, 'value': 0.5086740985455408},
#  {'area_number': 42, 'value': 0.5537996365472547},
#  {'area_number': 43, 'value': 0.5844441850571706},
#  {'area_number': 44, 'value': 0.589662649935522},
#  {'area_number': 45, 'value': 0.6141813100041732},
#  {'area_number': 46, 'value': 0.5626152611417037},
#  {'area_number': 47, 'value': 0.7420519705697473},
#  {'area_number': 48, 'value': 0.48239057325937423},
#  {'area_number': 49, 'value': 0.5878270645049916},
#  {'area_number': 50, 'value': 0.4736389003171844},
#  {'area_number': 51, 'value': 0.3981726505878982},
#  {'area_number': 52, 'value': 0.5321800043185244},
#  {'area_number': 53, 'value': 0.5811135908656084},
#  {'area_number': 54, 'value': 0.3930565036482148},
#  {'area_number': 55, 'value': 0.4732134631417814},
#  {'area_number': 56, 'value': 0.4509071741483006},
#  {'area_number': 57, 'value': 0.438658845319622},
#  {'area_number': 58, 'value': 0.5193858061523214},
#  {'area_number': 59, 'value': 0.5168419955664119},
#  {'area_number': 60, 'value': 0.44894519466191285},
#  {'area_number': 61, 'value': 0.4743999658186644},
#  {'area_number': 62, 'value': 0.4833179623761874},
#  {'area_number': 63, 'value': 0.5553938042876152},
#  {'area_number': 64, 'value': 0.4164350285776326},
#  {'area_number': 65, 'value': 0.5983395396870576},
#  {'area_number': 66, 'value': 0.6337640178536332},
#  {'area_number': 67, 'value': 0.5839681164974542},
#  {'area_number': 68, 'value': 0.6171983666394728},
#  {'area_number': 69, 'value': 0.5585560098054566},
#  {'area_number': 70, 'value': 0.5302845337480797},
#  {'area_number': 71, 'value': 0.5887104386613523},
#  {'area_number': 72, 'value': 0.23124893657946735},
#  {'area_number': 73, 'value': 0.5987474905699917},
#  {'area_number': 74, 'value': 0.33282297549029743},
#  {'area_number': 75, 'value': 0.4986962952615786},
#  {'area_number': 76, 'value': 0.43839145150425074},
#  {'area_number': 77, 'value': 0.4445677655886264}]

# %%
import pandas as pd
import requests
r = requests.get('http://18.117.9.77:5000/rent_burdened/min_burdened') #notice that by default, it is get
r.content
# Out:
# b'[\n  {\n    "area_number": 72, \n    "period_end_year": 2018, \n    "value": 0.185417748160549\n  }\n]\n'

# %%
data = r.json()
data
# Out:
# [{'area_number': 72, 'period_end_year': 2018, 'value': 0.185417748160549}]

# %%
#the section below is using the community.py . Never change this, this is an existing example and it should work.
import pandas as pd
import requests
r = requests.post('http://18.117.9.77:5000/community/metrics', json={'metrics':["total_population_2000"]}) #notice the post here
r.content
# Out:
# b'{\n  "metrics": [\n    {\n      "area_number": 1, \n      "name": "Rogers Park", \n      "part": "Far North Side"\n    }, \n    {\n      "area_number": 2, \n      "name": "West Ridge", \n      "part": "Far North Side"\n    }, \n    {\n      "area_number": 3, \n      "name": "Uptown", \n      "part": "Far North Side"\n    }, \n    {\n      "area_number": 4, \n      "name": "Lincoln Square", \n      "part": "Far North Side"\n    }, \n    {\n      "area_number": 5, \n      "name": "North Center", \n      "part": "North Side"\n    }, \n    {\n      "area_number": 6, \n      "name": "Lake View", \n      "part": "North Side"\n    }, \n    {\n      "area_number": 7, \n      "name": "Lincoln Park", \n      "part": "North Side"\n    }, \n    {\n      "area_number": 8, \n      "name": "Near North Side", \n      "part": "Central"\n    }, \n    {\n      "area_number": 9, \n      "name": "Edison Park", \n      "part": "Far North Side"\n    }, \n    {\n      "area_number": 10, \n      "name": "Norwood Park", \n      "part": "Far North Side"\n    }, \n    {\n      "area_number": 11, \n      "name": "Jefferson Park", \n      "part": "Far North Side"\n    }, \n    {\n      "area_number": 12, \n      "name": "Forest Glen", \n      "part": "Far North Side"\n    }, \n    {\n      "area_number": 13, \n      "name": "North Park", \n      "part": "Far North Side"\n    }, \n    {\n      "area_number": 14, \n      "name": "Albany Park", \n      "part": "Far North Side"\n    }, \n    {\n      "area_number": 15, \n      "name": "Portage Park", \n      "part": "Northwest Side"\n    }, \n    {\n      "area_number": 16, \n      "name": "Irving Park", \n      "part": "Northwest Side"\n    }, \n    {\n      "area_number": 17, \n      "name": "Dunning", \n      "part": "Northwest Side"\n    }, \n    {\n      "area_number": 18, \n      "name": "Montclare", \n      "part": "Northwest Side"\n    }, \n    {\n      "area_number": 19, \n      "name": "Belmont Cragin", \n      "part": "Northwest Side"\n    }, \n    {\n      "area_number": 20, \n      "name": "Hermosa", \n      "part": "Northwest Side"\n    }, \n    {\n      "area_number": 21, \n      "name": "Avondale", \n      "part": "North Side"\n    }, \n    {\n      "area_number": 22, \n      "name": "Logan Square", \n      "part": "North Side"\n    }, \n    {\n      "area_number": 23, \n      "name": "Humboldt Park", \n      "part": "West Side"\n    }, \n    {\n      "area_number": 24, \n      "name": "West Town", \n      "part": "West Side"\n    }, \n    {\n      "area_number": 25, \n      "name": "Austin", \n      "part": "West Side"\n    }, \n    {\n      "area_number": 26, \n      "name": "West Garfield Park", \n      "part": "West Side"\n    }, \n    {\n      "area_number": 27, \n      "name": "East Garfield Park", \n      "part": "West Side"\n    }, \n    {\n      "area_number": 28, \n      "name": "Near West Side", \n      "part": "West Side"\n    }, \n    {\n      "area_number": 29, \n      "name": "North Lawndale", \n      "part": "West Side"\n    }, \n    {\n      "area_number": 30, \n      "name": "South Lawndale", \n      "part": "West Side"\n    }, \n    {\n      "area_number": 31, \n      "name": "Lower West Side", \n      "part": "West Side"\n    }, \n    {\n      "area_number": 32, \n      "name": "Loop", \n      "part": "Central"\n    }, \n    {\n      "area_number": 33, \n      "name": "Near South Side", \n      "part": "Central"\n    }, \n    {\n      "area_number": 34, \n      "name": "Armour Square", \n      "part": "South Side"\n    }, \n    {\n      "area_number": 35, \n      "name": "Douglas", \n      "part": "South Side"\n    }, \n    {\n      "area_number": 36, \n      "name": "Oakland", \n      "part": "South Side"\n    }, \n    {\n      "area_number": 37, \n      "name": "Fuller Park", \n      "part": "South Side"\n    }, \n    {\n      "area_number": 38, \n      "name": "Grand Boulevard", \n      "part": "South Side"\n    }, \n    {\n      "area_number": 39, \n      "name": "Kenw ...

# %% [markdown]
# I will attempt to use my RBU metrics within the community.py file

# %%
#My attempt
import pandas as pd
import requests
r = requests.post('http://18.117.9.77:5000/community/metrics', json={'metrics':["rent_average"]})
r.content
data = r.json()
data
# Out:
# {'metrics': [{'area_number': 1,
#    'name': 'Rogers Park',
#    'part': 'Far North Side',
#    'rent_average': 0.5302510978679696},
#   {'area_number': 2,
#    'name': 'West Ridge',
#    'part': 'Far North Side',
#    'rent_average': 0.5097283445447782},
#   {'area_number': 3,
#    'name': 'Uptown',
#    'part': 'Far North Side',
#    'rent_average': 0.43211213106324214},
#   {'area_number': 4,
#    'name': 'Lincoln Square',
#    'part': 'Far North Side',
#    'rent_average': 0.35123187692461},
#   {'area_number': 5,
#    'name': 'North Center',
#    'part': 'North Side',
#    'rent_average': 0.32225627041653804},
#   {'area_number': 6,
#    'name': 'Lake View',
#    'part': 'North Side',
#    'rent_average': 0.33942125682913643},
#   {'area_number': 7,
#    'name': 'Lincoln Park',
#    'part': 'North Side',
#    'rent_average': 0.3385054789413935},
#   {'area_number': 8,
#    'name': 'Near North Side',
#    'part': 'Central',
#    'rent_average': 0.3495706737217485},
#   {'area_number': 9,
#    'name': 'Edison Park',
#    'part': 'Far North Side',
#    'rent_average': 0.33893145147465226},
#   {'area_number': 10,
#    'name': 'Norwood Park',
#    'part': 'Far North Side',
#    'rent_average': 0.42286894756722837},
#   {'area_number': 11,
#    'name': 'Jefferson Park',
#    'part': 'Far North Side',
#    'rent_average': 0.401999365909452},
#   {'area_number': 12,
#    'name': 'Forest Glen',
#    'part': 'Far North Side',
#    'rent_average': 0.40967282140644024},
#   {'area_number': 13,
#    'name': 'North Park',
#    'part': 'Far North Side',
#    'rent_average': 0.34330849046565104},
#   {'area_number': 14,
#    'name': 'Albany Park',
#    'part': 'Far North Side',
#    'rent_average': 0.43901106359040076},
#   {'area_number': 15,
#    'name': 'Portage Park',
#    'part': 'Northwest Side',
#    'rent_average': 0.4157247713333986},
#   {'area_number': 16,
#    'name': 'Irving Park',
#    'part': 'Northwest Side',
#    'rent_average': 0.4044859748794217},
#   {'area_number': 17,
#    'name': 'Dunning',
#    'part': 'Northwest Side',
#    'rent_average': 0.4771031485331919},
#   {'area_number': 18,
#    'name': 'Montclare',
#    'part': 'Northwest Side',
#    'rent_average': 0.5294937789435444},
#   {'area_number': 19,
#    'name': 'Belmont Cragin',
#    'part': 'Northwest Side',
#    'rent_average': 0.5568022009956136},
#   {'area_number': 20,
#    'name': 'Hermosa',
#    'part': 'Northwest Side',
#    'rent_average': 0.6077718584419536},
#   {'area_number': 21,
#    'name': 'Avondale',
#    'part': 'North Side',
#    'rent_average': 0.47377858881045926},
#   {'area_number': 22,
#    'name': 'Logan Square',
#    'part': 'North Side',
#    'rent_average': 0.3809871512534564},
#   {'area_number': 23,
#    'name': 'Humboldt Park',
#    'part': 'West Side',
#    'rent_average': 0.5453405908186649},
#   {'area_number': 24,
#    'name': 'West Town',
#    'part': 'West Side',
#    'rent_average': 0.35100620598223975},
#   {'area_number': 25,
#    'name': 'Austin',
#    'part': 'West Side',
#    'rent_average': 0.618917371580634},
#   {'area_number': 26,
#    'name': 'West Garfield Park',
#    'part': 'West Side',
#    'rent_average': 0.610321056562379},
#   {'area_number': 27,
#    'name': 'East Garfield Park',
#    'part': 'West Side',
#    'rent_average': 0.5769892800441351},
#   {'area_number': 28,
#    'name': 'Near West Side',
#    'part': 'West Side',
#    'rent_average': 0.4035301097271294},
#   {'area_number': 29,
#    'name': 'North Lawndale',
#    'part': 'West Side',
#    'rent_average': 0.6003365352695959},
#   {'area_number': 30,
#    'name': 'South Lawndale',
#    'part': 'West Side',
#    'rent_average': 0.5700280771301859},
#   {'area_number': 31,
#    'name': 'Lower West Side',
#    'part': 'West Side',
#    'rent_average': 0.4055336637396056},
#   {'area_number': 32,
#    'name': 'Loop',
#    'part': 'Central',
#    'rent_average': 0.35065459609223915},
#   {'area_number': 33,
#    'name': 'Near South Side',
#    'part': 'Central',
#    'rent_average': 0.4645410730297184},
#   {'area_number': 34,
#    'name': 'Armour Square',
#    'part': 'South Side',
#    'rent_average': 0.43351909690229795},
#   {'area_number': 35,
#    'name': 'Douglas',
#    'part': 'South Side',
#    'rent_average': 0.5485484578548134},
#   {'area_number': 36,
#    'name': 'Oakland',
#    'part': 'South Side',
#    'rent_average': 0.45494303455371},
#   {'area_number': 37,
#    'name': 'Fuller Park',
#    'part': 'South Side',
#    'rent_average': 0.6030153743235958},
#   {'area_number': 38,
#    'name': 'Grand Boulevard',
#    'part': 'South Side',
#    'rent_average': 0.5251129366003754},
#   {'area_number': 39,
#    'name': 'Kenwood',
#    'part': 'South Side',
#    'rent_average': 0.5044523809272752},
#   {'area_number': 40,
#    'name': 'Washington Park',
#    'part': 'South Side',
#    'rent_average': 0.5980414424092976},
#   {'area_number': 41,
#    'name': 'Hyde Park',
#    'part': 'South Side',
#    'rent_average': 0.5086740985455408},
#   {'area_number': 42,
#    'name': 'Woodlawn',
#    'part': 'South Side',
#    'rent_average': 0.5537996365472547},
#   {'area_number': 43,
#    'name': 'South Shore',
#    'part': 'South Side',
#    'rent_average': 0.5844441850571706},
#   {'area_number': 44,
#    'name': 'Chatham',
#    'part': 'Far Southeast Side',
#    'rent_average': 0.589662649935522},
#   {'area_number': 45,
#    'name': 'Avalon Park',
#    'part': 'Far Southeast Side',
#    'rent_average': 0.6141813100041732},
#   {'area_number': 46,
#    'name': 'South Chicago',
#    'part': 'Far Southeast Side',
#    'rent_average': 0.5626152611417037},
#   {'area_number': 47,
#    'name': 'Burnside',
#    'part': 'Far Southeast Side',
#    'rent_average': 0.7420519705697473},
#   {'area_number': 48,
#    'name': 'Calumet Heights',
#    'part': 'Far Southeast Side',
#    'rent_average': 0.48239057325937423},
#   {'area_number': 49,
#    'name': 'Roseland',
#    'part': 'Far Southeast Side',
#    'rent_average': 0.5878270645049916},
#   {'area_number': 50,
#    'name': 'Pullman',
#    'part': 'Far Southeast Side',
#    'rent_average': 0.4736389003171844},
#   {'area_number': 51,
#    'name': 'South Deering',
#    'part': 'Far Southeast Side',
#    'rent_average': 0.3981726505878982},
#   {'area_number': 52,
#    'name': 'East Side',
#    'part': 'Far Southeast Side',
#    'rent_average': 0.5321800043185244},
#   {'area_number': 53,
#    'name': 'West Pullman',
#    'part': 'Far Southeast Side',
#    'rent_average': 0.5811135908656084},
#   {'area_number': 54,
#    'name': 'Riverdale',
#    'part': 'Far Southeast Side',
#    'rent_average': 0.3930565036482148},
#   {'area_number': 55,
#    'name': 'Hegewisch',
#    'part': 'Far Southeast Side',
#    'rent_average': 0.4732134631417814},
#   {'area_number': 56,
#    'name': 'Garfield Ridge',
#    'part': 'Southwest Side',
#    'rent_average': 0.4509071741483006},
#   {'area_number': 57,
#    'name': 'Archer Heights',
#    'part': 'Southwest Side',
#    'rent_average': 0.438658845319622},
#   {'area_number': 58,
#    'name': 'Brighton Park',
#    'part': 'Southwest Side',
#    'rent_average': 0.5193858061523214},
#   {'area_number': 59,
#    'name': 'McKinley Park',
#    'part': 'Southwest Side',
#    'rent_average': 0.5168419955664119},
#   {'area_number': 60,
#    'name': 'Bridgeport',
#    'part': 'South Side',
#    'rent_average': 0.44894519466191285},
#   {'area_number': 61,
#    'name': 'New City',
#    'part': 'Southwest Side',
#    'rent_average': 0.4743999658186644},
#   {'area_number': 62,
#    'name': 'West Elsdon',
#    'part': 'Southwest Side',
#    'rent_average': 0.4833179623761874},
#   {'area_number': 63,
#    'name': 'Gage Park',
#    'part': 'Southwest Side',
#    'rent_average': 0.5553938042876152},
#   {'area_number': 64,
#    'name': 'Clearing',
#    'part': 'Southwest Side',
#    'rent_average': 0.4164350285776326},
#   {'area_number': 65,
#    'name': 'West Lawn',
#    'part': 'Southwest Side',
#    'rent_average': 0.5983395396870576},
#   {'area_number': 66,
#    'name': 'Chicago Lawn',
#    'part': 'Southwest Side',
#    'rent_average': 0.6337640178536332},
#   {'area_number': 67,
#    'name': 'West Englewood',
#    'part': 'Southwest Side',
#    'rent_average': 0.5839681164974542},
#   {'area_number': 68,
#    'name': 'Englewood',
#    'part': 'Southwest Side',
#    'rent_average': 0.6171983666394728},
#   {'area_number': 69,
#    'name': 'Greater Grand Crossing',
#    'part': 'South Side',
#    'rent_average': 0.5585560098054566},
#   {'area_number': 70,
#    'name': 'Ashburn',
#    'part': 'Far Southwest Side',
#    'rent_average': 0.5302845337480797},
#   {'area_number': 71,
#    'name': 'Auburn Gresham',
#    'part': 'Far Southwest Side',
#    'rent_average': 0.5887104386613523},
#   {'area_number': 72,
#    'name': 'Beverly',
#    'part': 'Far Southwest Side',
#    'rent_average': 0.23124893657946735},
#   {'area_number': 73,
#    'name': 'Washington Heights',
#    'part': 'Far Southwest Side',
#    'rent_average': 0.5987474905699917},
#   {'area_number': 74,
#    'name': 'Mount Greenwood',
#    'part': 'Far Southwest Side',
#    'rent_average': 0.33282297549029743},
#   {'area_number': 75,
#    'name': 'Morgan Park',
#    'part': 'Far Southwest Side',
#    'rent_average': 0.4986962952615786},
#   {'area_number': 76,
#    'name': "O'Hare",
#    'part': 'Far North Side',
#    'rent_average': 0.43839145150425074},
#   {'area_number': 77,
#    'name': 'Edgewater',
#    'part': 'Far North Side',
#    'rent_average': 0.4445677655886264}]}
