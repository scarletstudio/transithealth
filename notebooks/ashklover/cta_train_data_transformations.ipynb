# %%
import os
os.chdir("../../")

# %%
os.getcwd()
# Out:
# '/home/ec2-user/environment/transithealth'

# %%
import pandas as pd
import requests
from pipeline.utils.data import extract_data_portal_dates

# %%
dataset_json_url = "https://data.cityofchicago.org/resource/5neh-572f.json"
query = """
SELECT
    station_id,
    stationname,
    date,
    daytype,
    rides
WHERE
    date >= "2019-01-01" AND date <= "2020-12-31"
LIMIT 105000
"""
r = requests.get(dataset_json_url, params={"$query": query})
df = pd.DataFrame(r.json())
df
# Out:
#        station_id             stationname                     date daytype  \
# 0           40010      Austin-Forest Park  2019-01-01T00:00:00.000       U
# 1           40020             Harlem-Lake  2019-01-01T00:00:00.000       U
# 2           40030            Pulaski-Lake  2019-01-01T00:00:00.000       U
# 3           40040            Quincy/Wells  2019-01-01T00:00:00.000       U
# 4           40050                   Davis  2019-01-01T00:00:00.000       U
# ...           ...                     ...                      ...     ...
# 104559      41660              Lake/State  2020-12-31T00:00:00.000       W
# 104560      41670            Conservatory  2020-12-31T00:00:00.000       W
# 104561      41680           Oakton-Skokie  2020-12-31T00:00:00.000       W
# 104562      41690  Cermak-McCormick Place  2020-12-31T00:00:00.000       W
# 104563      41700       Washington/Wabash  2020-12-31T00:00:00.000       W
#
#        rides
# 0        576
# 1        981
# 2        835
# 3        929
# 4       1207
# ...      ...
# 104559  2563
# 104560   425
# 104561   142
# 104562   312
# 104563  1767
#
# [104564 rows x 5 columns]

# %%
print(type(df["date"][0]))
# Out:
# <class 'str'>

# %%
#def transformDate(old_date):

# %%
#df['ymd'] = transformDate(df['date'])

# %%
df = extract_data_portal_dates(df, col="date", prefix="")

# %%
df[1:50]
# Out:
#    station_id               stationname        date daytype rides         dt  \
# 1       40020               Harlem-Lake  2019-01-01       U   981 2019-01-01
# 2       40030              Pulaski-Lake  2019-01-01       U   835 2019-01-01
# 3       40040              Quincy/Wells  2019-01-01       U   929 2019-01-01
# 4       40050                     Davis  2019-01-01       U  1207 2019-01-01
# 5       40060            Belmont-O'Hare  2019-01-01       U  1608 2019-01-01
# 6       40070          Jackson/Dearborn  2019-01-01       U  1495 2019-01-01
# 7       40080                  Sheridan  2019-01-01       U  1839 2019-01-01
# 8       40090               Damen-Brown  2019-01-01       U   643 2019-01-01
# 9       40100                     Morse  2019-01-01       U  2021 2019-01-01
# 10      40120               35th/Archer  2019-01-01       U   754 2019-01-01
# 11      40130                      51st  2019-01-01       U   414 2019-01-01
# 12      40140           Dempster-Skokie  2019-01-01       U   378 2019-01-01
# 13      40150            Pulaski-Cermak  2019-01-01       U   527 2019-01-01
# 14      40160         LaSalle/Van Buren  2019-01-01       U   239 2019-01-01
# 12  2019-01  2019-01-06
# 13  2019-01  2019-01-06
# 14  2019-01  2019-01-06
# 15  2019-01  2019-01-06
# 16  2019-01  2019-01-06
# 17  2019-01  2019-01-06
# 18  2019-01  2019-01-06
# 19  2019-01  2019-01-06
# 20  2019-01  2019-01-06
# 21  2019-01  2019-01-06
# 22  2019-01  2019-01-06
# 23  2019-01  2019-01-06
# 24  2019-01  2019-01-06
# 25  2019-01  2019-01-06
# 26  2019-01  2019-01-06
# 27  2019-01  2019-01-06
# 28  2019-01  2019-01-06
# 29  2019-01  2019-01-06
# 30  2019-01  2019-01-06
# 31  2019-01  2019-01-06
# 32  2019-01  2019-01-06
# 33  2019-01  2019-01-06
# 34  2019-01  2019-01-06
# 35  2019-01  2019-01-06
# 36  2019-01  2019-01-06
# 37  2019-01  2019-01-06
# 38  2019-01  2019-01-06
# 39  2019-01  2019-01-06
# 40  2019-01  2019-01-06
# 41  2019-01  2019-01-06
# 42  2019-01  2019-01-06
# 43  2019-01  2019-01-06
# 44  2019-01  2019-01-06
# 45  2019-01  2019-01-06
# 46  2019-01  2019-01-06
# 47  2019-01  2019-01-06
# 48  2019-01  2019-01-06
# 49  2019-01  2019-01-06

# %%
dataset_json_url = "https://data.cityofchicago.org/resource/5neh-572f.json"
query = """
SELECT
    station_id,
    stationname,
    date,
    daytype,
    rides
WHERE
    date >= "2001-01-01" AND date <= "2021-02-28" AND
    stationname IN ('Howard', 'Wilson', 'Belmont', 'Fullerton', 'Merchandise Mart', 'Ashland', 'Roosevelt', 'Clinton', 'Clark/Lake', 'State/Lake', 'Lake', 'Washington', 'Washington/Wabash', 'Adams/Wabash', 'Jackson', 'Harold Washington Library', 'LaSalle/Van Buren', 'Quincy', 'Washington/Wells')
LIMIT 105000
"""
r = requests.get(dataset_json_url, params={"$query": query})
df = pd.DataFrame(r.json())
df
# Out:
#       station_id        stationname                     date daytype  rides
# 0          40540             Wilson  2017-12-22T00:00:00.000       W   4861
# 1          40260         State/Lake  2017-12-06T00:00:00.000       W  12646
# 2          40380         Clark/Lake  2017-12-20T00:00:00.000       W  20358
# 3          40730   Washington/Wells  2017-12-16T00:00:00.000       A   1256
# 4          41220          Fullerton  2017-12-28T00:00:00.000       W   4600
# ...          ...                ...                      ...     ...    ...
# 74988      41700  Washington/Wabash  2021-02-24T00:00:00.000       W   2449
# 74989      41700  Washington/Wabash  2021-02-25T00:00:00.000       W   2549
# 74990      41700  Washington/Wabash  2021-02-26T00:00:00.000       W   2658
# 74991      41700  Washington/Wabash  2021-02-27T00:00:00.000       A   1920
# 74992      41700  Washington/Wabash  2021-02-28T00:00:00.000       U   1203
#
# [74993 rows x 5 columns]
